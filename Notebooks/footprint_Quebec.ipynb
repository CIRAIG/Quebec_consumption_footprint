# %% [markdown]
# This notebook calculates the carbon footprint linked to the Quebec economy as described in the IO table generated in technology_matrix.ipynb and to the final demand vectors created for each quintile of Quebec households.

# %%
import pandas as pd
import numpy as np
import pymrio

# %%
path_to_exiobase_unzipped_folder = 'my_own_path/exiobase3.4/IOT_2011_pxp/'
io = pymrio.parse_exiobase3(path_to_exiobase_unzipped_folder)

# %% [markdown]
# To calculate the carbon footprint we will need the normalized emissions of EXIOBASE and its sectors. Pymrio does not generate normalized emissions from parsing exiobase. We need to calculate them first:

# %%
io.calc_all()

# %% [markdown]
# These emissions are in M€. Since our scale is the household, we bring back emissions to €:

# %%
io.satellite.S.loc[
    [i for i in io.satellite.S.index if io.satellite.unit.loc[i,'unit'] not in ['M.EUR','1000 p','M.hr']]
                    ]/=1000000

# %% [markdown]
# In the same fashion as with the technology matrix, we copy the normalized emissions of Canada and rename them QC.
#
# Note: direct emissions from technologies are considered the same in Canada and Quebec as technologies themselves were not changed.

# %%
S = io.satellite.S.copy()
S = pd.concat([S,S.loc[:,'CA']],axis=1)
S.columns = pd.MultiIndex.from_product([io.get_regions().tolist()+['QC'],io.get_sectors()],names=('region', 'sector'))
S[('QC','grid_mix')] = pd.Series(0, S.index)

# %% [markdown]
# To get to the catbon footprint, we need a characterization matrix matching each GHG emission to its Global Warming Pontential:

# %% [markdown]
# such a characterization matrix, directly matched to EXIOBASE flows can be found here: https://zenodo.org/record/3890339
#
# It uses the IMPACT World+ impact assessment methodology.

# %%
C = pd.read_csv('path_to_lonely_mountain/C_exio_IW.csv')
C = C.set_index('Unnamed: 0')
C = C.reindex(S.index,axis=1).fillna(0)

# %% [markdown]
# We got the emissions and impacts covered. Now let's load the technologies and households of Quebec that we produced before:

# %%
A = np.load('one_matrix_to_rule_them_all.npy')
index = pd.MultiIndex.from_product([io.get_regions().tolist()+['QC'],io.get_sectors()],names=['region','sector'])
index = index.tolist()+[('QC','grid_mix')]
A = pd.DataFrame(A, index=index, columns=index)

Y = pd.DataFrame(np.load('final_demand.npy'),index=A.index, columns=['1st_quintile','2nd_quintile','3rd_quintile','4th_quintile','5th_quintile'])

# %% [markdown]
# The determination of life cycle impacts follows the equation:

# %% [markdown]
# \begin{equation}
# \textbf{impacts} =
# \textbf{C} \cdot \textbf{S} \cdot(\textbf{I} - \textbf{A}) ^{-1} \cdot \textbf{y}
# \end{equation}

# %% [markdown]
# or:

# %% [markdown]
# \begin{equation}
# \textbf{impacts} =
# \textbf{C} \cdot \textbf{S} \cdot \textbf{L}
# \end{equation}

# %% [markdown]
# We already have S, y and A. We need to calculate L:

# %%
I = pd.DataFrame(np.eye(len(A)),A.index,A.columns)
L = pd.DataFrame(np.linalg.solve(I-A,Y),A.index, Y.columns)

# %% [markdown]
# Indirect emissions of the households, i.e., emissions coming from the production of good/service bought are:

# %%
indirect_emissions = S.dot(L)

# %% [markdown]
# To these indirect emissions, direct emissions must be added, i.e., emissions coming from the use by households of a good/service, e.g., using one's car. In fact, the previous equation was incomplete:

# %% [markdown]
# \begin{equation}
# \textbf{impacts} =
# \textbf{C} \cdot (\textbf{S} \cdot(\textbf{I} - \textbf{A}) ^{-1} \cdot \textbf{y} + \textbf{SY})
# \end{equation}

# %% [markdown]
# The direct emissions of the Canadian (matrix SY) will once again be adapted for Quebec. Again, we divide by 1,000,000 as the normalized emissions of the Canadian households are in M€.

# %%
direct_emissions = (pd.DataFrame(io.satellite.SY.loc[:, ('CA','Final consumption expenditure by households')])/1000000)
direct_emissions = pd.concat([direct_emissions]*5,axis=1)
direct_emissions.columns = Y.columns
direct_emissions *= Y.sum()

# %% [markdown]
# total emissions are defined as:

# %%
total_emissions = indirect_emissions + direct_emissions
total_emissions
# Out:
#                                                     1st_quintile  \
# Taxes less subsidies on products purchased: Total   8.377709e+02
# Other net taxes on production                       1.474382e+03
# Compensation of employees; wages, salaries, & e...  7.732065e+02
# Compensation of employees; wages, salaries, & e...  5.038692e+03
# Compensation of employees; wages, salaries, & e...  3.634125e+03
# Operating surplus: Consumption of fixed capital     4.377967e+03
# Operating surplus: Rents on land                    0.000000e+00
# Operating surplus: Royalties on resources           0.000000e+00
# Operating surplus: Remaining net operating surplus  7.121012e+03
# Employment: Low-skilled male                        6.537310e+01
# Employment: Low-skilled female                      3.565584e+01
# Employment: Medium-skilled male                     2.568489e+02
# Employment: Medium-skilled female                   1.581405e+02
# Employment: High-skilled male                       6.536043e+01
# Employment: High-skilled female                     4.824788e+01
# Employment hours: Low-skilled male                  1.395879e+02
# Employment hours: Low-skilled female                7.501404e+01
# Employment hours: Medium-skilled male               5.178865e+02
# Employment hours: Medium-skilled female             3.071540e+02
# Employment hours: High-skilled male                 1.203501e+02
# Employment hours: High-skilled female               8.296120e+01
# Employment: Vulnerable employment                   2.547404e+02
# Employment hours: Vulnerable employment             5.162048e+02
# CO2 - combustion - air                              1.247491e+04
# CH4 - combustion - air                              7.173745e+00
# N2O - combustion - air                              2.021495e-01
# SOx - combustion - air                              1.511312e+01
# NOx - combustion - air                              3.377057e+01
# NH3 - combustion - air                              2.992410e+00
# CO - combustion - air                               7.234736e+01
# ...                                                          ...
# Water Withdrawal Blue - Manufacturing - Radio, ...  6.596338e-07
# Water Withdrawal Blue - Manufacturing - Medical...  1.789926e-07
# Water Withdrawal Blue - Manufacturing - Motor v...  2.718381e-07
# Water Withdrawal Blue - Manufacturing - Other t...  1.032317e-08
# Water Withdrawal Blue - Manufacturing - Furnitu...  2.962142e-06
# Water Withdrawal Blue - Electricity - tower - E...  1.946718e-06
# Water Withdrawal Blue - Electricity - tower - E...  2.618825e-07
# Water Withdrawal Blue - Electricity - tower - E...  4.926730e-07
# Water Withdrawal Blue - Electricity - tower - E...  0.000000e+00
# Water Withdrawal Blue - Electricity - tower - E...  0.000000e+00
# Water Withdrawal Blue - Electricity - tower - E...  1.333280e-08
# Water Withdrawal Blue - Electricity - tower - E...  3.792141e-08
# Water Withdrawal Blue - Electricity - tower - E...  0.000000e+00
# Water Withdrawal Blue - Electricity - tower - E...  3.188261e-10
# Water Withdrawal Blue - Electricity - tower - E...  0.000000e+00
# Water Withdrawal Blue - Electricity - tower - E...  1.896704e-08
# Water Withdrawal Blue - Electricity - tower - E...  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  1.145309e-04
# Water Withdrawal Blue - Electricity - once-thro...  1.591443e-05
# Water Withdrawal Blue - Electricity - once-thro...  1.430999e-04
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  6.220051e-06
# Water Withdrawal Blue - Electricity - once-thro...  4.439764e-07
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  3.314922e-08
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00
# Water Withdrawal Blue - Domestic - domestic Wat...  2.017828e-04
#
#                                                     2nd_quintile  \
# Taxes less subsidies on products purchased: Total   1.229980e+03
# Other net taxes on production                       1.848995e+03
# Compensation of employees; wages, salaries, & e...  1.151410e+03
# Compensation of employees; wages, salaries, & e...  7.492575e+03
# Compensation of employees; wages, salaries, & e...  5.351354e+03
# Operating surplus: Consumption of fixed capital     6.081178e+03
# Operating surplus: Rents on land                    0.000000e+00
# Operating surplus: Royalties on resources           0.000000e+00
# Operating surplus: Remaining net operating surplus  9.710604e+03
# Employment: Low-skilled male                        9.535202e+01
# Employment: Low-skilled female                      5.155845e+01
# Employment: Medium-skilled male                     3.722049e+02
# Employment: Medium-skilled female                   2.291272e+02
# Employment: High-skilled male                       9.553905e+01
# Employment: High-skilled female                     6.929257e+01
# Employment hours: Low-skilled male                  2.033235e+02
# Employment hours: Low-skilled female                1.083012e+02
# Employment hours: Medium-skilled male               7.499598e+02
# Employment hours: Medium-skilled female             4.431911e+02
# Employment hours: High-skilled male                 1.761941e+02
# Employment hours: High-skilled female               1.194986e+02
# Employment: Vulnerable employment                   3.636013e+02
# Employment hours: Vulnerable employment             7.364169e+02
# CO2 - combustion - air                              1.910583e+04
# CH4 - combustion - air                              1.215108e+01
# N2O - combustion - air                              2.930544e-01
# SOx - combustion - air                              2.249660e+01
# NOx - combustion - air                              5.106062e+01
# NH3 - combustion - air                              4.382346e+00
# CO - combustion - air                               1.034204e+02
# ...                                                          ...
# Water Withdrawal Blue - Manufacturing - Radio, ...  1.236369e-06
# Water Withdrawal Blue - Manufacturing - Medical...  2.742396e-07
# Water Withdrawal Blue - Manufacturing - Motor v...  4.557472e-07
# Water Withdrawal Blue - Manufacturing - Other t...  1.481003e-08
# Water Withdrawal Blue - Manufacturing - Furnitu...  4.222719e-06
# Water Withdrawal Blue - Electricity - tower - E...  2.969196e-06
# Water Withdrawal Blue - Electricity - tower - E...  4.089179e-07
# Water Withdrawal Blue - Electricity - tower - E...  7.804457e-07
# Water Withdrawal Blue - Electricity - tower - E...  0.000000e+00
# Water Withdrawal Blue - Electricity - tower - E...  0.000000e+00
# Water Withdrawal Blue - Electricity - tower - E...  2.128466e-08
# Water Withdrawal Blue - Electricity - tower - E...  5.496111e-08
# Water Withdrawal Blue - Electricity - tower - E...  0.000000e+00
# Water Withdrawal Blue - Electricity - tower - E...  4.826246e-10
# Water Withdrawal Blue - Electricity - tower - E...  0.000000e+00
# Water Withdrawal Blue - Electricity - tower - E...  2.970083e-08
# Water Withdrawal Blue - Electricity - tower - E...  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  1.702825e-04
# Water Withdrawal Blue - Electricity - once-thro...  2.440246e-05
# Water Withdrawal Blue - Electricity - once-thro...  2.087771e-04
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  9.153003e-06
# Water Withdrawal Blue - Electricity - once-thro...  7.031059e-07
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  4.771747e-08
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00
# Water Withdrawal Blue - Domestic - domestic Wat...  2.851162e-04
#
#                                                     3rd_quintile  \
# Taxes less subsidies on products purchased: Total   1.797674e+03
# Other net taxes on production                       2.504323e+03
# Compensation of employees; wages, salaries, & e...  1.648157e+03
# Compensation of employees; wages, salaries, & e...  1.079406e+04
# Compensation of employees; wages, salaries, & e...  7.887205e+03
# Operating surplus: Consumption of fixed capital     8.508804e+03
# Operating surplus: Rents on land                    0.000000e+00
# Operating surplus: Royalties on resources           0.000000e+00
# Operating surplus: Remaining net operating surplus  1.341281e+04
# Employment: Low-skilled male                        1.381776e+02
# Employment: Low-skilled female                      7.548050e+01
# Employment: Medium-skilled male                     5.444465e+02
# Employment: Medium-skilled female                   3.418652e+02
# Employment: High-skilled male                       1.404870e+02
# Employment: High-skilled female                     1.074933e+02
# Employment hours: Low-skilled male                  2.956069e+02
# Employment hours: Low-skilled female                1.592135e+02
# Employment hours: Medium-skilled male               1.104109e+03
# Employment hours: Medium-skilled female             6.685131e+02
# Employment hours: High-skilled male                 2.589574e+02
# Employment hours: High-skilled female               1.838764e+02
# Employment: Vulnerable employment                   5.408985e+02
# Employment hours: Vulnerable employment             1.106312e+03
# CO2 - combustion - air                              2.637091e+04
# CH4 - combustion - air                              1.495004e+01
# N2O - combustion - air                              4.175414e-01
# SOx - combustion - air                              3.306921e+01
# NOx - combustion - air                              6.967172e+01
# NH3 - combustion - air                              6.555266e+00
# CO - combustion - air                               1.446505e+02
# ...                                                          ...
# Water Withdrawal Blue - Manufacturing - Radio, ...  1.639247e-06
# Water Withdrawal Blue - Manufacturing - Medical...  4.350233e-07
# Water Withdrawal Blue - Manufacturing - Motor v...  7.576025e-07
# Water Withdrawal Blue - Manufacturing - Other t...  2.163974e-08
# Water Withdrawal Blue - Manufacturing - Furnitu...  6.237495e-06
# Water Withdrawal Blue - Electricity - tower - E...  4.449708e-06
# Water Withdrawal Blue - Electricity - tower - E...  5.971001e-07
# Water Withdrawal Blue - Electricity - tower - E...  1.139146e-06
# Water Withdrawal Blue - Electricity - tower - E...  0.000000e+00
# Water Withdrawal Blue - Electricity - tower - E...  0.000000e+00
# Water Withdrawal Blue - Electricity - tower - E...  3.261835e-08
# Water Withdrawal Blue - Electricity - tower - E...  7.884704e-08
# Water Withdrawal Blue - Electricity - tower - E...  0.000000e+00
# Water Withdrawal Blue - Electricity - tower - E...  7.174442e-10
# Water Withdrawal Blue - Electricity - tower - E...  0.000000e+00
# Water Withdrawal Blue - Electricity - tower - E...  4.432293e-08
# Water Withdrawal Blue - Electricity - tower - E...  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  2.448225e-04
# Water Withdrawal Blue - Electricity - once-thro...  3.512590e-05
# Water Withdrawal Blue - Electricity - once-thro...  2.862675e-04
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  1.306803e-05
# Water Withdrawal Blue - Electricity - once-thro...  1.037984e-06
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  6.963728e-08
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00
# Water Withdrawal Blue - Domestic - domestic Wat...  4.039211e-04
#
#                                                     4th_quintile  5th_quintile
# Taxes less subsidies on products purchased: Total   2.287748e+03  3.309334e+03
# Other net taxes on production                       3.030058e+03  4.159734e+03
# Compensation of employees; wages, salaries, & e...  2.096693e+03  3.069062e+03
# Compensation of employees; wages, salaries, & e...  1.374951e+04  2.027601e+04
# Compensation of employees; wages, salaries, & e...  9.842017e+03  1.466180e+04
# Operating surplus: Consumption of fixed capital     1.045915e+04  1.480233e+04
# Operating surplus: Rents on land                    0.000000e+00  0.000000e+00
# Operating surplus: Royalties on resources           0.000000e+00  0.000000e+00
# Operating surplus: Remaining net operating surplus  1.649289e+04  2.307464e+04
# Employment: Low-skilled male                        1.777215e+02  2.525973e+02
# Employment: Low-skilled female                      9.747392e+01  1.382444e+02
# Employment: Medium-skilled male                     7.002452e+02  9.869706e+02
# Employment: Medium-skilled female                   4.446082e+02  6.449889e+02
# Employment: High-skilled male                       1.773864e+02  2.648221e+02
# Employment: High-skilled female                     1.341748e+02  2.106315e+02
# Employment hours: Low-skilled male                  3.807356e+02  5.408726e+02
# Employment hours: Low-skilled female                2.059578e+02  2.916900e+02
# Employment hours: Medium-skilled male               1.423779e+03  2.011218e+03
# Employment hours: Medium-skilled female             8.724364e+02  1.261978e+03
# Employment hours: High-skilled male                 3.276107e+02  4.859982e+02
# Employment hours: High-skilled female               2.298561e+02  3.569314e+02
# Employment: Vulnerable employment                   7.022371e+02  9.783656e+02
# Employment hours: Vulnerable employment             1.441230e+03  2.015792e+03
# CO2 - combustion - air                              3.399018e+04  4.940812e+04
# CH4 - combustion - air                              2.005235e+01  2.906397e+01
# N2O - combustion - air                              5.280318e-01  7.554441e-01
# SOx - combustion - air                              4.249757e+01  6.190920e+01
# NOx - combustion - air                              8.964326e+01  1.290418e+02
# NH3 - combustion - air                              8.724471e+00  1.307094e+01
# CO - combustion - air                               1.806876e+02  2.547413e+02
# ...                                                          ...           ...
# Water Withdrawal Blue - Manufacturing - Radio, ...  2.292359e-06  3.434397e-06
# Water Withdrawal Blue - Manufacturing - Medical...  5.707600e-07  8.468549e-07
# Water Withdrawal Blue - Manufacturing - Motor v...  9.601074e-07  1.552391e-06
# Water Withdrawal Blue - Manufacturing - Other t...  2.805502e-08  4.157105e-08
# Water Withdrawal Blue - Manufacturing - Furnitu...  8.935694e-06  1.424792e-05
# Water Withdrawal Blue - Electricity - tower - E...  5.724643e-06  8.374361e-06
# Water Withdrawal Blue - Electricity - tower - E...  7.543422e-07  1.113111e-06
# Water Withdrawal Blue - Electricity - tower - E...  1.435437e-06  2.126884e-06
# Water Withdrawal Blue - Electricity - tower - E...  0.000000e+00  0.000000e+00
# Water Withdrawal Blue - Electricity - tower - E...  0.000000e+00  0.000000e+00
# Water Withdrawal Blue - Electricity - tower - E...  4.089801e-08  6.216221e-08
# Water Withdrawal Blue - Electricity - tower - E...  9.925790e-08  1.422601e-07
# Water Withdrawal Blue - Electricity - tower - E...  0.000000e+00  0.000000e+00
# Water Withdrawal Blue - Electricity - tower - E...  9.188503e-10  1.322609e-09
# Water Withdrawal Blue - Electricity - tower - E...  0.000000e+00  0.000000e+00
# Water Withdrawal Blue - Electricity - tower - E...  5.600172e-08  8.325675e-08
# Water Withdrawal Blue - Electricity - tower - E...  0.000000e+00  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  3.086111e-04  4.385190e-04
# Water Withdrawal Blue - Electricity - once-thro...  4.478134e-05  6.499601e-05
# Water Withdrawal Blue - Electricity - once-thro...  3.559016e-04  4.900775e-04
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  1.661164e-05  2.390871e-05
# Water Withdrawal Blue - Electricity - once-thro...  1.312527e-06  1.984786e-06
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00  0.000000e+00
# Water Withdrawal Blue - Electricity - once-thro...  8.724499e-08  1.273028e-07
# Water Withdrawal Blue - Electricity - once-thro...  0.000000e+00  0.000000e+00
# Water Withdrawal Blue - Domestic - domestic Wat...  5.028833e-04  7.234063e-04
#
# [1104 rows x 5 columns]

# %% [markdown]
# Multiply with the characterization factors to get the carbon footprint:

# %%
impact_category = 'Climate change, short term (kg CO2 eq (short))'

GWP_per_quintile_per_household = pd.DataFrame(C.dot(total_emissions).loc[impact_category])

# %% [markdown]
# Note that sinc ethe begining we are talking about € because that is the currency used in EXIOBASE. We thus need to apply a convertion rate, for the year of reference. You can find convertion rates here (https://www.statista.com/statistics/412804/euro-to-canadian-dollar-average-annual-exchange-rate/). Our reference year is 2011, so:

# %%
GWP_per_quintile_per_household /= 1.38

# %% [markdown]
# Carbon footprint (in kgCO2eq) per household in Quebec is therefore:

# %%
GWP_per_quintile_per_household
# Out:
#               Climate change, short term (kg CO2 eq (short))
# 1st_quintile                                    13255.210581
# 2nd_quintile                                    20063.035735
# 3rd_quintile                                    27986.498012
# 4th_quintile                                    35856.978648
# 5th_quintile                                    51583.616755

# %% [markdown]
# We can also look at the carbon footprint per dollar spent:

# %%
GWP_per_quintile_per_dollar = GWP_per_quintile_per_household.T/Y.sum()
GWP_per_quintile_per_dollar.T
# Out:
#               Climate change, short term (kg CO2 eq (short))
# 1st_quintile                                        0.572737
# 2nd_quintile                                        0.613518
# 3rd_quintile                                        0.604094
# 4th_quintile                                        0.621669
# 5th_quintile                                        0.621702

# %% [markdown]
# Or if we scale up to all of Quebec (assuming 3,411,000 households https://www.stat.gouv.qc.ca/statistiques/conditions-vie-societe/depenses-avoirs-dettes/depenses/effectif.htm)

# %%
GWP_quebec_total = GWP_per_quintile_per_household.sum().sum()*3411000/5
GWP_quebec_total
# Out:
# 101474070764.91489

# %% [markdown]
# The calculated carbon footprint of Quebec in 2011 is therefore 101.5MtCO2eq. Which makes about 12tCO2eq/capita that year.
